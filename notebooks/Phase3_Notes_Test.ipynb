# %%
# Load Transcript

with open(
    "../outputs/transcript.txt",
    "r",
    encoding="utf-8"
) as f:

    transcript = f.read()

# %%
# Prompt

prompt = f"""

Generate:

1 Summary

2 Key Points

3 Detailed Notes

Text:

{transcript}

"""

# %%
# Generate

notes = ask_gemini(prompt)

print(notes)
